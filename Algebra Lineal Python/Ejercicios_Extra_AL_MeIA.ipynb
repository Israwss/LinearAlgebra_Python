# %% [markdown]
# ![logo_MeIA.png](data:image/png;base64,...)

# %% [markdown]
# # ÁLGEBRA LINEAL
#
# CAROLINA MALDONADO-
# VALERIA RULLONI

# %%
#primero importamos las librerías de python necesarias
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# %% [markdown]
# # VECTORES

# %% [markdown]
# ## Operaciones.
#
# Suma y resta de vectores.
#
# Multiplicación de un escalar por un vector.

# %% [markdown]
# ## Combinaciones lineales.

# %% [markdown]
# ### Ejercicio:
#
# Realice las siguientes operaciones, en papel y en código:
#
# $5\begin{bmatrix}
# 3\\
# 2\\
# 0
# \end{bmatrix} + \begin{bmatrix}
# 1\\
# 1.1\\
# 4
# \end{bmatrix}= $
#
# $
#  \begin{bmatrix}
# 4.5\\
# -3\\
# 12
# \end{bmatrix}+23 \begin{bmatrix}
# 1.5\\
# 3\\
# 5
# \end{bmatrix} = $
#
# $5 \begin{bmatrix}
# -3\\
# 3\\
# 0
# \end{bmatrix} + 2 \begin{bmatrix}
# 0 \\
# -1\\
# 3
# \end{bmatrix}+ (3) \begin{bmatrix}
# -8\\
# 7\\
# -2
# \end{bmatrix}+ (-1)\begin{bmatrix}
# -1\\
# 2\\
# 4
# \end{bmatrix}=$

# %%
#hacer en codigo

# %% [markdown]
# # MATRICES
#
# Ejercicio:
#
# Defina la matriz:
#
# $A= \begin{bmatrix}
# 2 & 0.5 & -1\\\
# 0.5 & 1 & -1\\
# 5 & -1\ & 7
# \end{bmatrix}$ y la identidad $3 \times 3$. Realice una combinación linea de ambas

# %% [markdown]
# Ejercicio:
# + Escribir en código dos matrices: A de tamaño $3\times 4$ y B otra de tamaño $4\times 5$ puede realizar la multiplicación matricial $A*B$ o $B*A$?
# + Calcular, en papel y en código. Verificar que tamaño tiene la matriz resultante.
# * Calcular la traspuesta de A, verificar que tamaño tiene
# + Alguna de estas matrices es cuadrada?
# * Verificar que se cumple la propiedad Trasposición del producto: $(AB)^T=B^TA^T$

# %% [markdown]
# ### Ejercicio
#
# Defina
# una matriz diagonal una triangular inferior de tamaño $3 \times 3$ y sus traspuestas. Analizar las traspuestas, son diagonales o triangulares?

# %% [markdown]
# ### Ejercicio
# Defina A, una matriz cuadrada $3\times 3$ que sea inversible, calcular su matriz reducida por filas y su matriz inversa $A^{-1}$).
# Verifiar que cumple: $AA^{-1}=A^{-1}A=I_{3\times 3}$.

# %% [markdown]
# Ejercicio: realizar en papel la reducción por filas de la matriz A y cotejar con los resultados del código

# %%
# Ejemplo 1 
#La primera matriz ya esta declarada como A, declaramos la segunda:
A1=np.array([[1,3],
            [-1, 4]])
#Mostramos cada una de ellas
print('la matriz A es', A)
print('la matriz A1 es', A1)
#Mostramos el producto de ambas

print('El producto de A por A1 es',np.dot(A,A1))
# Out:
# la matriz A es [[ 2.   0. ]
#  [ 0.5 -1. ]
#  [ 4.   7. ]]
# la matriz A1 es [[ 1  3]
#  [-1  4]]
# El producto de A por A1 es [[ 2.   6. ]
#  [ 1.5 -2.5]
#  [-3.  40. ]]

# %%
#Ejercicio: realizar el Ejemplo 2, mostrando cada una de las matrices y el producto entre ellas sugerido.

# %%
# Ejemplo 3. En caso de que consideremos vectores el producto se toma como producto punto de vectores

C=np.array([-1,0.5,4])

C1=np.array([2,-3,5])
#Mostramos cada una de ellas
print('la matriz C es', C)
print('la matriz C1 es', C1)
#Mostramos el producto de ambas

print('El producto de A por A1 es',np.dot(C,C1))
# Out:
# la matriz C es [-1.   0.5  4. ]
# la matriz C1 es [ 2 -3  5]
# El producto de A por A1 es 16.5

# %%
#Consideremos este ejemplo que muestra que  el producto matricial no es conmutativo en general.
A1=np.array([[1,3],
            [-1, 4]])
A2=np.array([[9,0],
            [1, -2]])
print('El producto de A1 por A2 es:')
print(np.dot(A1,A2))

print('El producto de A2 por A1 es:')
print(np.dot(A2,A1))
# Out:
# El producto de A1 por A2 es:
# [[12 -6]
#  [-5 -8]]
# El producto de A2 por A1 es:
# [[ 9 27]
#  [ 3 -5]]

# %% [markdown]
# # SISTEMAS DE ECUACIONES LINEALES
#
# Ejercicio: Llevarlo a expresión matricial y resolver el sistema de ecuaciones lineales:
#
# $\left\{\begin{matrix}
# -2x+3y+5z&=0  \\
# 8y-z&=0\\
#  4x+z&=0
# \end{matrix}\right.$

# %% [markdown]
# Ejercicio: Llevarlo a expresión matricial y resolver el sistema de ecuaciones lineales:
#
# $\left\{\begin{matrix}
# x+8z=-3  \\
# 2x+9y+2z=0\\
#  5x+2y=7
# \end{matrix}\right.$

# %% [markdown]
# # ESPACIOS VECTORIALES

# %% [markdown]
# Recordemos la definición de **norma euclídea**, denotada por $\left \| . \right \|$
# $$ \left \| (x_1,x_2)  \right \| =\sqrt{x_1^2+x_2^2}$$
#
# Este concepto nos permite hablar de la **distancia entre dos vectores** que definimos como la norma de laresta de ellos.
# $$d(u,v)=\left \| u-v \right \|$$.

# %% [markdown]
# ### Ejercicio
# Sean los vectores:
# $u=(1,2,1)$, $v=(3,2.-1)$ y $w=(1,-1.-1)$
#
# Calcular la norma de cada uno, la distancia entre ellos y si son ortogonales.
# Cuáles son los más cercanos?

# %% [markdown]
# # TRANSFORMACIONES LINEALES

# %% [markdown]
# ## Valores y vectores propios de una matriz (autovalores y autovectores)

# %% [markdown]
# Ejercicio: sea la transformación lineal dada por la matriz $A= \begin{bmatrix}
# 2 & 2\\
# 2 & 2\\
# \end{bmatrix} $
# es decir $T(X)=AX$
#
# verificar cuales de los vectores son vectores propios de A:
#
# $X= \begin{bmatrix}
# 3\\
# 3\\
# \end{bmatrix} $
#
# $Y= \begin{bmatrix}
# 1\\
# -2\\
# \end{bmatrix} $

# %% [markdown]
# ## Ejercicio:
#
# Realizar la descomposición en Valores Singulares de la matriz:
# $A= \begin{bmatrix}
# 6 & 2\\
# 6 & 5\\
# 1 & 1\\
# \end{bmatrix} $

# %%
#Hacemos SVD a una matriz en R3x2 e interpretamos
#import numpy as np
D=np.array([[6,2],
            [6,5],
            [1,1]])
r,c=np.shape(D)

# %%
#Ejercicio: chequear que las columnas de V son ortonormales. 
#Ejercicio: chequear que las columnas de T son ortogonales.
